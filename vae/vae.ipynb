# %%
from __future__ import print_function
from __future__ import absolute_import
from __future__ import division


import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
n_samples = mnist.train.num_examples

tf.reset_default_graph()

np.random.seed(0)
tf.set_random_seed(0)

def xavier_init(fan_in, fan_out, constant=1):
    low = -constant*np.sqrt(6.0/(fan_in + fan_out))
    high = constant*np.sqrt(6.0/(fan_in + fan_out))
    return [low, high]
#     return tf.random_uniform([fan_in, fan_out],
#                              minval=low,
#                              maxval=high,
#                              dtype=tf.float32)

class VAEModel():
    def __init__(self, network_arch, lr, batch_size):
        # Setup network variables
        self.network_arch = network_arch
        self.lr = lr
        self.nonlin = tf.nn.softplus
        self.batch_size = batch_size
        self.sess = tf.InteractiveSession()

        # Setup placeholders
        self.x = tf.placeholder(tf.float32, [None, 784])
        
        # Setup VAE architecture
        self._create_network()
        
        # Setup optimizer
        self._create_optimizer()
        
        # Initialize the variables
        init = tf.global_variables_initializer()

        self.sess.run(init)
        writer = tf.summary.FileWriter('./graph_log_dir', sess.graph)
        writer.close()
        
    def _create_network(self):
        self.recognition_network = self._recognition_network(784, 500, 500, 20)
        pass
    
    def _initialize_weights(self, n_input, n_hidden_recog1, n_hidden_recog2, \
                            n_z, n_hidden_gener_1, n_hidden_gener_2):
        pass
    
    def _recognition_network(self, n1, n2, n3, n4):
        with tf.variable_scope("recog"):
            with tf.variable_scope("weights"):
                h1_xav = xavier_init(n1, n2)
                h1 = tf.get_variable("h1", [n1, n2], 
                                     initializer=tf.random_uniform_initializer(h1_xav[0], h1_xav[1]))
                h2_xav = xavier_init(n2, n3)
                h2 = tf.get_variable("h2", [n2, n3], 
                                     initializer=tf.random_uniform_initializer(h2_xav[0], h2_xav[1]))
                out_mean_xav = xavier_init(n3, n4)
                out_mean_h = tf.get_variable("out_mean", [n3, n4],
                                           initializer=tf.random_uniform_initializer(
                                               out_mean_xav[0], out_mean_xav[1]))
                out_log_sigma_xav = xavier_init(n3, n4)
                out_log_sigma_h = tf.get_variable("out_log_sigma", [n3, n4],
                                              initializer=tf.random_uniform_initializer(
                                                  out_log_sigma_xav[0], out_log_sigma_xav[1]))
            with tf.variable_scope("biases"):
                b1 = tf.get_variable("b1", [n2],
                                     initializer=tf.constant_initializer(0))
                b2 = tf.get_variable("b2", [n3], 
                                     initializer=tf.constant_initializer(0))
                out_mean_b = tf.get_variable("out_mean", [n4],
                                             initializer=tf.constant_initializer(0))
                out_log_sigma_b = tf.get_variable("out_log_sigma", [n4],
                                                initializer=tf.constant_initializer(0))

            layer_1 = self.nonlin(tf.add(tf.matmul(self.x, h1), b1))
            layer_2 = self.nonlin(tf.add(tf.matmul(h1, h2), b2))
            z_mean  = tf.add(tf.matmul(layer_2, out_mean_h), out_mean_b)
            z_log_sigma_sq = tf.add(tf.matmul(layer_2, out_log_sigma_h), out_log_sigma_b)
            
        return (z_mean, z_log_sigma_sq)
    
    def _generative_network(self):
        with tf.variable_scope("gener"):
            pass
    
    def _create_optimizer(self):
        pass
    
    def generate(self):
        pass
    
    def reconstruct(self):
        pass
    
    def transform(self):
        pass
    
def train():
    pass

def partial_fit():
    pass

def main():
    vae = VAEModel([784, 500, 500], 0.001, 128)
    print("Done!")
    

if __name__ == '__main__':
    main()
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Done!
